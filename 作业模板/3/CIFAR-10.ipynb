# %% [markdown]
# # MindSpore实战二，CIFAR-10图像分类

# %% [markdown]
# 数据集介绍：
# * CIFAR-10数据集由10个类的60000个32x32彩色图像组成，每个类有6000个图像。有50000个训练图像和10000个测试图像。数据集分为五个训练批次和一个测试批次，每个批次有10000个图像。测试批次包含来自每个类别的恰好1000个随机选择的图像。训练批次以随机的顺序输入图像，但一些训练批次可能包含来自一个类别的图像比另一个更多。总体来说，五个训练集之和包含来自每个类的正好5000张图像。
# * 10个类完全相互排斥，且类之间没有重叠，汽车和卡车之间没有重叠。“汽车”包括轿车，SUV等。“卡车”只包括大卡车，不包括皮卡车。
# * CIFAR-10数据集官网：https://www.cs.toronto.edu/~kriz/cifar.html
#
# <img src="image/01.png">

# %% [markdown]
# 本实验使用MindSpore深度学习框架，演示一个完整的图像分类模型开发流程。
#
# 实验流程（新增数据展示、模型优化、模型重训练预评估）：
#
# <img src="image/02.png">
#
# 注意：
# 1. 请确保存储路径只有英文，否则可能报错。
# 2. 第二次运行请先清空results文件夹，否则可能报错。

# %% [markdown]
# ## 环境准备
# * Mindspore模块主要用于本次实验卷积神经网络的构建，包括很多子模块。
#     * mindspore.dataset：包括CIFAR-10数据集的载入与处理，也可以自定义数据集。
#
#     * mindspore.common：包中会有诸如type形态转变、权重初始化等的常规工具。
#
#     * mindspore.nn：主要包括网络可能涉及到的各类网络层，诸如卷积层、池化层、全连接层，也包括损失函数，激活函数等。
#
#     * mindspore.train.callback：涉及到各类回调函数，如checkpoint，lossMonitor等，也可以自定义Callback。
#
#     * context：设定mindspore的运行环境与运行设备。
#
#     * Model：承载网络结构，并能够调用优化器、损失函数、评价指标。
#
#     * save_checkpoint, load_checkpoint：保存与读取最佳网络参数。
#
# 本实验需要以下第三方库：
# 1. MindSpore 1.7
# 2. Numpy 1.17.5
# 3. matplotlib 3.3.4

# %% [markdown]
# Python 环境导入

# %%
import mindspore

# mindspore.dataset
import mindspore.dataset as ds # 数据集的载入
import mindspore.dataset.transforms.c_transforms as C # 常用转化算子
import mindspore.dataset.vision.c_transforms as CV # 图像转化算子

# mindspore.common
from mindspore.common import dtype as mstype # 数据形态转换
from mindspore.common.initializer import Normal # 参数初始化

# mindspore.nn
import mindspore.nn as nn # 各类网络层都在nn里面
from mindspore.nn.metrics import Accuracy, Loss # 测试模型用

# mindspore.train.callback
from mindspore.train.callback import ModelCheckpoint, CheckpointConfig, LossMonitor, TimeMonitor, Callback # 回调函数


from mindspore import Model # 承载网络结构
from mindspore import save_checkpoint, load_checkpoint # 保存与读取最佳参数
from mindspore import context # 设置mindspore运行的环境


import numpy as np # numpy
import matplotlib.pyplot as plt # 可视化用
import copy # 保存网络参数用

# 数据路径处理
import os, stat

# %% [markdown]
# MindSpore 环境设置
#
# MindSpore支持两种运行模式，在调试或者运行方面做了不同的优化：
# * PYNATIVE模式：也称动态图模式，将神经网络中的各个算子逐一下发执行，方便用户编写和调试神经网络模型。
# * GRAPH模式：也称静态图模式或者图模式，将神经网络模型编译成一整张图，然后下发执行。该模式利用图优化等技术提高运行性能，同时有助于规模部署和跨平台运行。

# %%
device_target = context.get_context('device_target') # 获取运行装置（CPU，GPU，Ascend）
dataset_sink_mode = True if device_target in ['Ascend','GPU'] else False # 是否将数据通过pipeline下发到装置上
context.set_context(mode = context.GRAPH_MODE, device_target = device_target) # 设置运行环境，静态图context.GRAPH_MODE指向静态图模型，即在运行之前会把全部图建立编译完毕

print(f'device_target: {device_target}')
print(f'dataset_sink_mode: {dataset_sink_mode}')
# Out:
# device_target: Ascend
# dataset_sink_mode: True

# %% [markdown]
# ## 数据展示
# 查看数据集

# %%
# 数据路径
train_path = os.path.join('cifar-10-batches-bin') # 训练集路径
test_path = os.path.join('cifar-10-verify-bin') # 测试集路径
print(f'训练集路径：{train_path}')
print(f'测试集路径：{test_path}')
# Out:
# 训练集路径：cifar-10-batches-bin
# 测试集路径：cifar-10-verify-bin

# %%
# 创建图像标签列表
category_dict = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',
                 6:'frog',7:'horse',8:'ship',9:'truck'}

# 载入展示用数据
demo_data = ds.Cifar10Dataset(test_path)

# 设置图像大小
plt.figure(figsize=(6, 6))

# 打印9张子图
i = 1
for dic in demo_data.create_dict_iterator():
    plt.subplot(3,3,i)
    plt.imshow(dic['image'].asnumpy()) # asnumpy：将 MindSpore tensor 转换成 numpy
    plt.axis('off')
    plt.title(category_dict[dic['label'].asnumpy().item()])
    i +=1
    if i > 9 :
        break

plt.show()

# %% [markdown]
# ## 数据处理

# %% [markdown]
# 计算数据集平均数和标准差，数据标准化时使用

# %%
ds_train = ds.Cifar10Dataset(train_path)
#计算数据集平均数和标准差，数据标准化时使用
tmp = np.asarray( [x['image'] for x in ds_train.create_dict_iterator(output_numpy=True)] )
RGB_mean = tuple(np.mean(tmp, axis=(0, 1, 2)))
RGB_std = tuple(np.std(tmp, axis=(0, 1, 2)))

print(RGB_mean)
print(RGB_std)
# Out:
# (125.306918046875, 122.950394140625, 113.86538318359375)
# (62.99321927772611, 62.088707640335784, 66.70489964067369)

# %% [markdown]
# 定义数据预处理函数
#
# 函数功能包括：
# 1. 加载数据集
# 1. 打乱数据集
# 1. 图像特征处理（包括尺寸大小变更、平移、标准化、训练时的随机裁剪、随机翻转等）
# 3. 批量输出数据
# 4. 重复

# %%
def create_dataset(data_path, batch_size = 32, repeat_num=1, usage = 'train'):
    """ 
    数据处理
    
    Args:
        data_path (str): 数据路径
        batch_size (int): 批量大小
        usage (str): 训练或测试
        
    Returns:
        Dataset对象
    """
    
    # 载入数据集
    data = ds.Cifar10Dataset(data_path)
    
    # 打乱数据集
    data = data.shuffle(buffer_size=10000)
    
    # 定义算子
    if usage=='train':
        trans = [
            CV.Normalize(RGB_mean, RGB_std), # 数据标准化

            # 数据增强
            CV.RandomCrop([32, 32], [4, 4, 4, 4]), # 随机裁剪
            CV.RandomHorizontalFlip(), # 随机翻转

            CV.HWC2CHW() # 通道前移（为配适网络，CHW的格式可最佳发挥昇腾芯片算力）
        ]
    else:
        trans = [
            CV.Normalize(RGB_mean, RGB_std), # 数据标准化
            CV.HWC2CHW() # 通道前移（为配适网络，CHW的格式可最佳发挥昇腾芯片算力）
        ]
    
    typecast_op = C.TypeCast(mstype.int32) # 原始数据的标签是unint，计算损失需要int

    # 算子运算
    data = data.map(input_columns='label', operations=typecast_op)
    data = data.map(input_columns='image', operations=trans)
    
    # 批处理
    data = data.batch(batch_size, drop_remainder=True)
    
    # 重复
    data = data.repeat(repeat_num)
    
    return data

# %% [markdown]
# ## 网络定义

# %% [markdown]
# 使用“MindSpore实战一”中介绍的网络，LeNet5

# %%
class LeNet5(nn.Cell):
    """
    LeNet5网络

    Args:
        num_class (int): 输出分类数
        num_channel (int): 输入通道数
    Returns:
        Tensor, 输出张量

    Examples:
        >>> LeNet5(10, 3)
    """
    
    # 定义算子
    def __init__(self, num_class=10, num_channel=3):
        super(LeNet5, self).__init__()
        # 卷积层
        self.conv1 = nn.Conv2d(num_channel, 6, 5, pad_mode='valid')
        self.conv2 = nn.Conv2d(6, 16, 5, pad_mode='valid')
        
        # 全连接层
        self.fc1 = nn.Dense(16 * 5 * 5, 120, weight_init=Normal(0.02))
        self.fc2 = nn.Dense(120, 84, weight_init=Normal(0.02))
        self.fc3 = nn.Dense(84, num_class, weight_init=Normal(0.02))
        
        # 激活函数
        self.relu = nn.ReLU()
        
        # 最大池化成
        self.max_pool2d = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # 网络展开
        self.flatten = nn.Flatten()

    # 建构网络
    def construct(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# ## 模型训练

# %% [markdown]
# 载入数据

# %%
train_data = create_dataset(train_path, batch_size = 32, usage = 'train') # 训练数据集
test_data = create_dataset(test_path, batch_size = 50, usage= 'test') # 测试数据集

# %% [markdown]
# 构建网络、损失函数、优化器、模型

# %%
# 网络
network1 = LeNet5(10)

# 损失函数
net_loss = nn.SoftmaxCrossEntropyWithLogits(sparse=True, reduction='mean')

# 优化器
net_opt = nn.Momentum(params=network1.trainable_params(), learning_rate=0.01, momentum=0.9)

# 模型
model = Model(network = network1, loss_fn=net_loss, optimizer=net_opt, metrics={'accuracy': Accuracy(), 'loss':Loss()})

# %% [markdown]
# 定义记录loss的Callback，每个epoch结束时记录
#
# Callback介绍：
# https://www.mindspore.cn/docs/zh-CN/r1.7/api_python/mindspore.train.html#mindspore.train.callback.Callback
#
# 自定义Callback教程：https://www.mindspore.cn/tutorials/zh-CN/r1.7/advanced/train/callback.html

# %%
# 记录模型每个epoch的loss
class TrainHistroy(Callback):
    """
    记录模型训练时每个epoch的loss的回调函数

    Args:
        history (list): 传入list以保存模型每个epoch的loss
    """
    
    def __init__(self, history):
        super(TrainHistroy, self).__init__()
        self.history = history
        
    # 每个epoch结束时执行
    def epoch_end(self, run_context):
        cb_params = run_context.original_args()
        loss = cb_params.net_outputs.asnumpy()
        self.history.append(loss)
        

# 测试并记录模型在测试集的loss和accuracy，每个epoch结束时进行模型测试并记录结果，跟踪并保存准确率最高的模型网络参数
class EvalHistory(Callback):
    """
    记录模型训练时每个epoch在测试集的loss和accuracy的回调函数，并保存准确率最高的模型网络参数

    Args:
        model (Cell): 模型，评估loss和accuracy用
        loss_history (list): 传入list以保存模型每个epoch在测试集的loss
        acc_history (list): 传入list以保存模型每个epoch在测试集的accuracy
        eval_data (Dataset): 测试集，评估模型loss和accuracy用
    """
    
    #保存accuracy最高的网络参数
    best_param = None
    
    def __init__(self, model, loss_history, acc_history, eval_data):
        super(EvalHistory, self).__init__()
        self.loss_history = loss_history
        self.acc_history = acc_history
        self.eval_data = eval_data
        self.model = model
    
    # 每个epoch结束时执行
    def epoch_end(self, run_context):
        cb_params = run_context.original_args()
        res = self.model.eval(self.eval_data, dataset_sink_mode=False)
        
        if len(self.acc_history)==0 or res['accuracy']>=max(self.acc_history):
            self.best_param = copy.deepcopy(cb_params.network)
            
        self.loss_history.append(res['loss'])
        self.acc_history.append(res['accuracy'])
        
        print('acc_eval: ',res['accuracy'])
    
    # 训练结束后执行
    def end(self, run_context):
        # 保存最优网络参数
        best_param_path = os.path.join(ckpt_path, 'best_param.ckpt')
        
        if os.path.exists(best_param_path):
            # best_param.ckpt已存在时MindSpore会覆盖旧的文件，这里修改文件读写权限防止报错
            os.chmod(best_param_path, stat.S_IWRITE)
            
        save_checkpoint(self.best_param, best_param_path)

# %% [markdown]
# 设置回调函数（Callback）

# %%
ckpt_path = os.path.join('.','results') # 网络参数保存路径
hist = {'loss':[], 'loss_eval':[], 'acc_eval':[]} # 训练过程记录

# 网络参数自动保存，这里设定每2000个step保存一次，最多保存10次
config_ck = CheckpointConfig(save_checkpoint_steps=2000,
                             keep_checkpoint_max=10)
ckpoint_cb = ModelCheckpoint(prefix='checkpoint_lenet', directory=ckpt_path, config=config_ck)

# 监控每次迭代的时间
time_cb = TimeMonitor(data_size=ds_train.get_dataset_size())

# 监控loss值
loss_cb = LossMonitor(per_print_times=500)

# 记录每次迭代的模型损失值
train_hist_cb = TrainHistroy(hist['loss'])

# 测试并记录模型在验证集的loss和accuracy，并保存最优网络参数
eval_hist_cb = EvalHistory(model = model,
                           loss_history = hist['loss_eval'], 
                           acc_history = hist['acc_eval'], 
                           eval_data = test_data)

# %% [markdown]
# 训练模型

# %%
epoch = 10 # 迭代次数
# 开始训练
model.train(epoch, train_data, callbacks=[train_hist_cb, eval_hist_cb, time_cb, ckpoint_cb, loss_cb], dataset_sink_mode=dataset_sink_mode)
# Out:
# [WARNING] ME(13892:24816,MainProcess):2023-05-27-18:44:15.867.81 [mindspore\train\model.py:1077] For TrainHistroy callback, {'epoch_end'} methods may not be supported in later version, Use methods prefixed with 'on_train' or 'on_eval' instead when using customized callbacks.
# [WARNING] ME(13892:24816,MainProcess):2023-05-27-18:44:15.877.81 [mindspore\train\model.py:1077] For EvalHistory callback, {'epoch_end', 'end'} methods may not be supported in later version, Use methods prefixed with 'on_train' or 'on_eval' instead when using customized callbacks.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 epoch = 10 # 迭代次数
#       2 # 开始训练
# ----> 3 model.train(epoch, train_data, callbacks=[train_hist_cb, eval_hist_cb, time_cb, ckpoint_cb, loss_cb], dataset_sink_mode=dataset_sink_mode)
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\train\model.py:1046, in Model.train(self, epoch, train_dataset, callbacks, dataset_sink_mode, sink_size, initial_epoch)
#    1043 if callbacks:
#    1044     self._check_methods_for_custom_callbacks(callbacks, "train")
# -> 1046 self._train(epoch,
#    1047             train_dataset,
#    1048             callbacks=callbacks,
#    1049             dataset_sink_mode=dataset_sink_mode,
#    1050             sink_size=sink_size,
#    1051             initial_epoch=initial_epoch)
#    1053 # When it's Parameter Server training and using MindRT,
#    1054 # the node id should be reset to start from 0.
#    1055 if _enable_distributed_mindrt():
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\train\model.py:98, in _save_final_ckpt.<locals>.wrapper(self, *args, **kwargs)
#      96         raise e
#      97 else:
# ---> 98     func(self, *args, **kwargs)
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\train\model.py:618, in Model._train(self, epoch, train_dataset, callbacks, dataset_sink_mode, sink_size, initial_epoch, valid_dataset, valid_frequency, valid_dataset_sink_mode)
#     616 self._check_reuse_dataset(train_dataset)
#     617 if not dataset_sink_mode:
# --> 618     self._train_process(epoch, train_dataset, list_callback, cb_params, initial_epoch, valid_infos)
#     619 elif context.get_context("device_target") == "CPU":
#     620     logger.info("The CPU cannot support dataset sink mode currently."
#     621                 "So the training process will be performed with dataset not sink.")
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\train\model.py:909, in Model._train_process(self, epoch, train_dataset, list_callback, cb_params, initial_epoch, valid_infos)
#     907 list_callback.on_train_step_begin(run_context)
#     908 self._check_network_mode(self._train_network, True)
# --> 909 outputs = self._train_network(*next_element)
#     910 cb_params.net_outputs = outputs
#     911 if self._loss_scale_manager and self._loss_scale_manager.get_drop_overflow_update():
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\nn\cell.py:619, in Cell.__call__(self, *args, **kwargs)
#     616     if self._hook_fn_registered():
#     617         logger.warning(f"For 'Cell', it's not support hook function in graph mode. If you want to use hook "
#     618                        f"function, please use context.set_context to set pynative mode.")
# --> 619     out = self.compile_and_run(*args)
#     620     return out
#     622 # Run in PyNative mode.
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\nn\cell.py:1005, in Cell.compile_and_run(self, *inputs)
#     992 """
#     993 Compile and run Cell, the input must be consistent with the input defined in construct.
#     994
#    (...)
#    1002     Object, the result of executing.
#    1003 """
#    1004 self._auto_parallel_compile_and_run = True
# -> 1005 self.compile(*inputs)
#    1007 new_inputs = _get_args_for_run(self, inputs)
#    1008 return _cell_graph_executor(self, *new_inputs, phase=self.phase)
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\nn\cell.py:976, in Cell.compile(self, *inputs)
#     969 """
#     970 Compile Cell as a computation graph, the input must be consistent with the input defined in construct.
#     971
#     972 Args:
#     973     inputs (tuple): Inputs of the Cell object.
#     974 """
#     975 if self._dynamic_shape_inputs is None or self._dynamic_shape_inputs[0] is None:
# --> 976     _cell_graph_executor.compile(self, *inputs, phase=self.phase, auto_parallel_mode=self._auto_parallel_mode,
#     977                                  jit_config_dict=self._jit_config_dict)
#     978 else:
#     979     self._check_compile_dynamic_shape(*inputs)
#
# File d:\Desktop\专业创新实践\虚拟环境\MindSpore\lib\site-packages\mindspore\common\api.py:1131, in _CellGraphExecutor.compile(self, obj, phase, do_convert, auto_parallel_mode, jit_config_dict, *args)
#    1129 if jit_config_dict:
#    1130     self._graph_executor.set_jit_config(jit_config_dict)
# -> 1131 result = self._graph_executor.compile(obj, args_list, phase, self._use_vm_mode())
#    1132 obj.compile_cache.add(phase)
#    1133 if not result:
#
# ValueError: For 'Conv2d', input shape's h and w after padding must be greater than or equal to kernel_size's h and w respectively.
#
# ----------------------------------------------------
# - C++ Call Stack: (For framework developers)
# ----------------------------------------------------
# mindspore\core\ops\conv2d.cc:243 Conv2dInferShape
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。请查看单元格中的代码，以确定故障的可能原因。有关详细信息，请单击 <a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>。有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %% [markdown]
# ## 模型评估
# 注意：测试集不会进行随机裁剪与翻转。

# %% [markdown]
# 观察模型loss的变化

# %%
# 定义loss记录绘制函数
def plot_loss(hist):
    plt.plot(hist['loss'], marker='.')
    plt.plot(hist['loss_eval'], marker='.')
    plt.title('loss record')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend(['loss_train', 'loss_eval'], loc='upper right')
    plt.show()
    plt.close()

plot_loss(hist)

# %% [markdown]
# 观察模型accuracy变化

# %%
def plot_accuracy(hist):
    plt.plot(hist['acc_eval'], marker='.')
    plt.title('accuracy history')
    plt.xlabel('epoch')
    plt.ylabel('acc_eval')
    plt.grid()
    plt.show()
    plt.close()

plot_accuracy(hist)

# %% [markdown]
# 载入最佳网络参数，并测试其accuracy与loss

# %%
# 使用准确率最高的参数组合建立模型，并测试其在验证集上的效果
load_checkpoint(os.path.join(ckpt_path, 'best_param.ckpt'), net=network1)
res = model.eval(test_data, dataset_sink_mode=dataset_sink_mode)
print(res)
# Out:
# {'accuracy': 0.5864, 'loss': 1.1943483406305313}

# %% [markdown]
# ## 模型优化
# Lenet网络本身的复杂度并不足以对CIFAR-10的图像分类任务产生出足够的拟合效果，因此需要做进一步改进。总的来说，网络基本维持了lenet的网络结构，增加卷积的个数与卷积核的大小，同时略微增加了网络的深度。
# 1.	所有的卷积核从5∗5变成3∗3。
# 2.	增加了一层网络的深度，提升模型的非线性映射能力。
# 3.	提升了卷积核数量，使模型可以提取更多的特征，如32核，64核，128核。

# %%
import mindspore.ops.operations as ops
class LeNet5_2(nn.Cell):
    def __init__(self, num_class=10, num_channel=3):
        super(LeNet5_2, self).__init__()
        self.resize = ops.ResizeBilinear((64, 64))
        self.conv1 = nn.Conv2d(num_channel, 32, 3, pad_mode='valid', weight_init=Normal(0.02))
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3, pad_mode='valid', weight_init=Normal(0.02))
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, 3, pad_mode='valid', weight_init=Normal(0.02))
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, 3, pad_mode='valid', weight_init=Normal(0.02))
        self.bn4 = nn.BatchNorm2d(256)
        self.fc1 = nn.Dense(256 * 2 * 2, 1024, weight_init=Normal(0.02))
        self.fc2 = nn.Dense(1024, 1024, weight_init=Normal(0.02))
        self.fc3 = nn.Dense(1024, num_class, weight_init=Normal(0.02))
        self.relu = nn.ReLU()
        self.max_pool2d = nn.MaxPool2d(kernel_size=2, stride=2)
        self.flatten = nn.Flatten()
        self.num_class = num_class
    
    def construct(self, x):
        x = self.resize(x)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.conv4(x)
        x = self.bn4(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# 数据预处理不做调整，重新创建训练集合测试集。

# %%
# 训练数据集预处理
train_data = create_dataset(train_path, batch_size = 50, usage = 'train')
# 测试数据集预处理
test_data = create_dataset(test_path, batch_size = 80, usage = 'test')

# %% [markdown]
# 构建新的网络、损失函数、优化器、模型

# %%
# 网络
network2 = LeNet5_2(10)

# 损失函数
net_loss = nn.SoftmaxCrossEntropyWithLogits(sparse=True, reduction='mean')

# 优化器
net_opt = nn.Adam(params=network2.trainable_params())

# 模型
model = Model(network = network2, loss_fn=net_loss, optimizer=net_opt, metrics={'accuracy': Accuracy(), 'loss':Loss()})

# %% [markdown]
# 定义新的Callback

# %%
hist = {'loss':[], 'loss_eval':[], 'acc_eval':[]} # 训练过程记录

# 网络参数自动保存，这里设定每2000个step保存一次，最多保存10次
config_ck = CheckpointConfig(save_checkpoint_steps=2000, keep_checkpoint_max=10)
ckpoint_cb = ModelCheckpoint(prefix='checkpoint_lenet_2', directory=ckpt_path, config=config_ck)

# 记录每次迭代的模型准确率
train_hist_cb = TrainHistroy(hist['loss'])

# 测试并记录模型在验证集的loss和accuracy，并保存最优网络参数
eval_hist_cb = EvalHistory(model = model,
                           loss_history = hist['loss_eval'], 
                           acc_history = hist['acc_eval'], 
                           eval_data = test_data)

# %% [markdown]
# ## 重新训练与评估
# 优化了模型的网络结构并改用Adam优化器，数据预处理、模型训练的超参数与损失函数没做调整。

# %%
epoch = 100 # 迭代次数
# 开始训练
model.train(epoch, train_data, 
            callbacks=[train_hist_cb, eval_hist_cb, time_cb, ckpoint_cb, LossMonitor(per_print_times=500)], 
            dataset_sink_mode=dataset_sink_mode)
# Out:
# epoch: 1 step: 1000, loss is 1.0951619148254395
# acc_eval:  0.6229
# epoch time: 42497.157 ms, per step time: 42.497 ms
# epoch: 2 step: 1000, loss is 0.8033854961395264
# acc_eval:  0.7038
# epoch time: 5462.785 ms, per step time: 5.463 ms
# epoch: 3 step: 1000, loss is 0.7317368984222412
# acc_eval:  0.7546
# epoch time: 5253.624 ms, per step time: 5.254 ms
# epoch: 4 step: 1000, loss is 0.6855192184448242
# acc_eval:  0.7346
# epoch time: 5364.058 ms, per step time: 5.364 ms
# epoch: 5 step: 1000, loss is 0.7676063776016235
# acc_eval:  0.7758
# epoch time: 5226.529 ms, per step time: 5.227 ms
# epoch: 6 step: 1000, loss is 0.5739061236381531
# acc_eval:  0.8003
# epoch time: 5445.069 ms, per step time: 5.445 ms
# epoch: 7 step: 1000, loss is 0.5582773685455322
# acc_eval:  0.8014
# epoch time: 5256.973 ms, per step time: 5.257 ms
# epoch: 8 step: 1000, loss is 0.4298332631587982
# acc_eval:  0.8136
# epoch time: 5470.042 ms, per step time: 5.470 ms
# epoch: 9 step: 1000, loss is 0.5937049984931946
# acc_eval:  0.8199
# epoch time: 5249.371 ms, per step time: 5.249 ms
# epoch: 10 step: 1000, loss is 0.61600261926651
# acc_eval:  0.8263
# epoch time: 5390.245 ms, per step time: 5.390 ms
# epoch: 11 step: 1000, loss is 0.41674506664276123
# acc_eval:  0.8259
# epoch time: 5206.318 ms, per step time: 5.206 ms
# epoch: 12 step: 1000, loss is 0.4431923031806946
# acc_eval:  0.8349
# epoch time: 5377.098 ms, per step time: 5.377 ms
# epoch: 13 step: 1000, loss is 0.47362077236175537
# acc_eval:  0.8444
# epoch time: 5253.673 ms, per step time: 5.254 ms
# epoch: 14 step: 1000, loss is 0.47693902254104614
# acc_eval:  0.8336
# epoch time: 5321.644 ms, per step time: 5.322 ms
# epoch: 15 step: 1000, loss is 0.5311775803565979
# acc_eval:  0.8438
# epoch time: 5181.700 ms, per step time: 5.182 ms
# epoch: 16 step: 1000, loss is 0.4645111560821533
# acc_eval:  0.8458
# epoch time: 5320.792 ms, per step time: 5.321 ms
# epoch: 17 step: 1000, loss is 0.44431185722351074
# acc_eval:  0.8517
# epoch time: 5265.223 ms, per step time: 5.265 ms
# epoch: 18 step: 1000, loss is 0.6085808277130127
# acc_eval:  0.855
# epoch time: 5344.083 ms, per step time: 5.344 ms
# epoch: 19 step: 1000, loss is 0.250532865524292
# acc_eval:  0.8537
# epoch time: 5173.818 ms, per step time: 5.174 ms
# epoch: 20 step: 1000, loss is 0.5036038160324097
# acc_eval:  0.8501
# epoch time: 5330.866 ms, per step time: 5.331 ms
# epoch: 21 step: 1000, loss is 0.2890533208847046
# acc_eval:  0.8513
# epoch time: 5263.536 ms, per step time: 5.264 ms
# epoch: 22 step: 1000, loss is 0.4095851182937622
# acc_eval:  0.8571
# epoch time: 5331.717 ms, per step time: 5.332 ms
# epoch: 23 step: 1000, loss is 0.4105972349643707
# acc_eval:  0.8567
# epoch time: 5172.619 ms, per step time: 5.173 ms
# epoch: 24 step: 1000, loss is 0.5389349460601807
# acc_eval:  0.8567
# epoch time: 5351.890 ms, per step time: 5.352 ms
# epoch: 25 step: 1000, loss is 0.5100471377372742
# acc_eval:  0.8641
# epoch time: 5236.969 ms, per step time: 5.237 ms
# epoch: 26 step: 1000, loss is 0.2590762972831726
# acc_eval:  0.8645
# epoch time: 5351.728 ms, per step time: 5.352 ms
# epoch: 27 step: 1000, loss is 0.34280750155448914
# acc_eval:  0.8594
# epoch time: 5207.712 ms, per step time: 5.208 ms
# epoch: 28 step: 1000, loss is 0.3288465142250061
# acc_eval:  0.8674
# epoch time: 5401.170 ms, per step time: 5.401 ms
# epoch: 29 step: 1000, loss is 0.27998223900794983
# acc_eval:  0.8668
# epoch time: 5189.806 ms, per step time: 5.190 ms
# epoch: 30 step: 1000, loss is 0.34615036845207214
# acc_eval:  0.8684
# epoch time: 5396.875 ms, per step time: 5.397 ms
# epoch: 31 step: 1000, loss is 0.28028589487075806
# acc_eval:  0.8676
# epoch time: 5196.058 ms, per step time: 5.196 ms
# epoch: 32 step: 1000, loss is 0.3117044270038605
# acc_eval:  0.8728
# epoch time: 5417.569 ms, per step time: 5.418 ms
# epoch: 33 step: 1000, loss is 0.34836626052856445
# acc_eval:  0.872
# epoch time: 5274.830 ms, per step time: 5.275 ms
# epoch: 34 step: 1000, loss is 0.15719690918922424
# acc_eval:  0.8679
# epoch time: 5346.334 ms, per step time: 5.346 ms
# epoch: 35 step: 1000, loss is 0.15355564653873444
# acc_eval:  0.8628
# epoch time: 5144.013 ms, per step time: 5.144 ms
# epoch: 36 step: 1000, loss is 0.3071407079696655
# acc_eval:  0.8685
# epoch time: 5316.331 ms, per step time: 5.316 ms
# epoch: 37 step: 1000, loss is 0.20991697907447815
# acc_eval:  0.8704
# epoch time: 5175.233 ms, per step time: 5.175 ms
# epoch: 38 step: 1000, loss is 0.13783085346221924
# acc_eval:  0.8677
# epoch time: 5365.450 ms, per step time: 5.365 ms
# epoch: 39 step: 1000, loss is 0.1840406358242035
# acc_eval:  0.8676
# epoch time: 5198.920 ms, per step time: 5.199 ms
# epoch: 40 step: 1000, loss is 0.18180185556411743
# acc_eval:  0.8729
# epoch time: 5344.109 ms, per step time: 5.344 ms
# epoch: 41 step: 1000, loss is 0.18570849299430847
# acc_eval:  0.8674
# epoch time: 5187.200 ms, per step time: 5.187 ms
# epoch: 42 step: 1000, loss is 0.1892838329076767
# acc_eval:  0.8724
# epoch time: 5279.929 ms, per step time: 5.280 ms
# epoch: 43 step: 1000, loss is 0.23650848865509033
# acc_eval:  0.8659
# epoch time: 5188.038 ms, per step time: 5.188 ms
# epoch: 44 step: 1000, loss is 0.15264280140399933
# acc_eval:  0.8698
# epoch time: 5296.442 ms, per step time: 5.296 ms
# epoch: 45 step: 1000, loss is 0.37424996495246887
# acc_eval:  0.8715
# epoch time: 5178.171 ms, per step time: 5.178 ms
# epoch: 46 step: 1000, loss is 0.13152658939361572
# acc_eval:  0.8755
# epoch time: 5366.128 ms, per step time: 5.366 ms
# epoch: 47 step: 1000, loss is 0.17331811785697937
# acc_eval:  0.8679
# epoch time: 5251.099 ms, per step time: 5.251 ms
# epoch: 48 step: 1000, loss is 0.30098116397857666
# acc_eval:  0.8778
# epoch time: 5359.704 ms, per step time: 5.360 ms
# epoch: 49 step: 1000, loss is 0.11289291083812714
# acc_eval:  0.8739
# epoch time: 5207.927 ms, per step time: 5.208 ms
# epoch: 50 step: 1000, loss is 0.19562140107154846
# acc_eval:  0.876
# epoch time: 5356.885 ms, per step time: 5.357 ms
# epoch: 51 step: 1000, loss is 0.41985997557640076
# acc_eval:  0.8736
# epoch time: 5203.910 ms, per step time: 5.204 ms
# epoch: 52 step: 1000, loss is 0.059248682111501694
# acc_eval:  0.8747
# epoch time: 5381.064 ms, per step time: 5.381 ms
# epoch: 53 step: 1000, loss is 0.15799161791801453
# acc_eval:  0.8764
# epoch time: 5204.208 ms, per step time: 5.204 ms
# epoch: 54 step: 1000, loss is 0.2238764613866806
# acc_eval:  0.873
# epoch time: 5317.495 ms, per step time: 5.317 ms
# epoch: 55 step: 1000, loss is 0.08705774694681168
# acc_eval:  0.8769
# epoch time: 5225.795 ms, per step time: 5.226 ms
# epoch: 56 step: 1000, loss is 0.2039923071861267
# acc_eval:  0.8726
# epoch time: 5306.369 ms, per step time: 5.306 ms
# epoch: 57 step: 1000, loss is 0.4738331437110901
# acc_eval:  0.8721
# epoch time: 5199.813 ms, per step time: 5.200 ms
# epoch: 58 step: 1000, loss is 0.1296660453081131
# acc_eval:  0.8727
# epoch time: 5334.712 ms, per step time: 5.335 ms
# epoch: 59 step: 1000, loss is 0.25403982400894165
# acc_eval:  0.8727
# epoch time: 5183.647 ms, per step time: 5.184 ms
# epoch: 60 step: 1000, loss is 0.0730198323726654
# acc_eval:  0.8778
# epoch time: 5424.890 ms, per step time: 5.425 ms
# epoch: 61 step: 1000, loss is 0.2343924641609192
# acc_eval:  0.8745
# epoch time: 5185.721 ms, per step time: 5.186 ms
# epoch: 62 step: 1000, loss is 0.2204810231924057
# acc_eval:  0.8784
# epoch time: 5347.374 ms, per step time: 5.347 ms
# epoch: 63 step: 1000, loss is 0.11079639941453934
# acc_eval:  0.8742
# epoch time: 5210.827 ms, per step time: 5.211 ms
# epoch: 64 step: 1000, loss is 0.18825936317443848
# acc_eval:  0.8755
# epoch time: 5334.561 ms, per step time: 5.335 ms
# epoch: 65 step: 1000, loss is 0.12131078541278839
# acc_eval:  0.879
# epoch time: 5279.849 ms, per step time: 5.280 ms
# epoch: 66 step: 1000, loss is 0.24835631251335144
# acc_eval:  0.8763
# epoch time: 5368.142 ms, per step time: 5.368 ms
# epoch: 67 step: 1000, loss is 0.16589507460594177
# acc_eval:  0.8844
# epoch time: 5328.237 ms, per step time: 5.328 ms
# epoch: 68 step: 1000, loss is 0.10965543985366821
# acc_eval:  0.8731
# epoch time: 5291.419 ms, per step time: 5.291 ms
# epoch: 69 step: 1000, loss is 0.21895276010036469
# acc_eval:  0.8758
# epoch time: 5191.252 ms, per step time: 5.191 ms
# epoch: 70 step: 1000, loss is 0.08986515551805496
# acc_eval:  0.8761
# epoch time: 5351.758 ms, per step time: 5.352 ms
# epoch: 71 step: 1000, loss is 0.22162693738937378
# acc_eval:  0.8717
# epoch time: 5198.830 ms, per step time: 5.199 ms
# epoch: 72 step: 1000, loss is 0.2778417468070984
# acc_eval:  0.8824
# epoch time: 5380.290 ms, per step time: 5.380 ms
# epoch: 73 step: 1000, loss is 0.09076157957315445
# acc_eval:  0.8814
# epoch time: 5216.506 ms, per step time: 5.217 ms
# epoch: 74 step: 1000, loss is 0.2833338677883148
# acc_eval:  0.8766
# epoch time: 5296.718 ms, per step time: 5.297 ms
# epoch: 75 step: 1000, loss is 0.09705439954996109
# acc_eval:  0.8752
# epoch time: 5168.236 ms, per step time: 5.168 ms
# epoch: 76 step: 1000, loss is 0.1175849437713623
# acc_eval:  0.8743
# epoch time: 5334.121 ms, per step time: 5.334 ms
# epoch: 77 step: 1000, loss is 0.2674146890640259
# acc_eval:  0.8778
# epoch time: 5236.682 ms, per step time: 5.237 ms
# epoch: 78 step: 1000, loss is 0.10227760672569275
# acc_eval:  0.8767
# epoch time: 5369.246 ms, per step time: 5.369 ms
# epoch: 79 step: 1000, loss is 0.1358945518732071
# acc_eval:  0.8772
# epoch time: 5249.537 ms, per step time: 5.250 ms
# epoch: 80 step: 1000, loss is 0.09776175767183304
# acc_eval:  0.8772
# epoch time: 5675.982 ms, per step time: 5.676 ms
# epoch: 81 step: 1000, loss is 0.15197023749351501
# acc_eval:  0.8727
# epoch time: 5218.456 ms, per step time: 5.218 ms
# epoch: 82 step: 1000, loss is 0.19530518352985382
# acc_eval:  0.8794
# epoch time: 5386.266 ms, per step time: 5.386 ms
# epoch: 83 step: 1000, loss is 0.02857169881463051
# acc_eval:  0.8787
# epoch time: 5263.765 ms, per step time: 5.264 ms
# epoch: 84 step: 1000, loss is 0.13661178946495056
# acc_eval:  0.882
# epoch time: 5377.789 ms, per step time: 5.378 ms
# epoch: 85 step: 1000, loss is 0.28889065980911255
# acc_eval:  0.8778
# epoch time: 5198.776 ms, per step time: 5.199 ms
# epoch: 86 step: 1000, loss is 0.14454811811447144
# acc_eval:  0.8791
# epoch time: 5340.253 ms, per step time: 5.340 ms
# epoch: 87 step: 1000, loss is 0.0809241384267807
# acc_eval:  0.8831
# epoch time: 5237.679 ms, per step time: 5.238 ms
# epoch: 88 step: 1000, loss is 0.22864367067813873
# acc_eval:  0.8829
# epoch time: 5353.556 ms, per step time: 5.354 ms
# epoch: 89 step: 1000, loss is 0.0613413080573082
# acc_eval:  0.8823
# epoch time: 5200.561 ms, per step time: 5.201 ms
# epoch: 90 step: 1000, loss is 0.10476473718881607
# acc_eval:  0.8827
# epoch time: 5359.472 ms, per step time: 5.359 ms
# epoch: 91 step: 1000, loss is 0.18115800619125366
# acc_eval:  0.8809
# epoch time: 5214.018 ms, per step time: 5.214 ms
# epoch: 92 step: 1000, loss is 0.12636663019657135
# acc_eval:  0.8775
# epoch time: 5339.928 ms, per step time: 5.340 ms
# epoch: 93 step: 1000, loss is 0.14462488889694214
# acc_eval:  0.8822
# epoch time: 5215.525 ms, per step time: 5.216 ms
# epoch: 94 step: 1000, loss is 0.13702957332134247
# acc_eval:  0.8801
# epoch time: 5373.836 ms, per step time: 5.374 ms
# epoch: 95 step: 1000, loss is 0.08451120555400848
# acc_eval:  0.88
# epoch time: 5200.646 ms, per step time: 5.201 ms
# epoch: 96 step: 1000, loss is 0.2835698425769806
# acc_eval:  0.88
# epoch time: 5317.018 ms, per step time: 5.317 ms
# epoch: 97 step: 1000, loss is 0.20076999068260193
# acc_eval:  0.8811
# epoch time: 5228.881 ms, per step time: 5.229 ms
# epoch: 98 step: 1000, loss is 0.026938840746879578
# acc_eval:  0.8842
# epoch time: 5334.735 ms, per step time: 5.335 ms
# epoch: 99 step: 1000, loss is 0.14543256163597107
# acc_eval:  0.8826
# epoch time: 5191.886 ms, per step time: 5.192 ms
# epoch: 100 step: 1000, loss is 0.05186930671334267
# acc_eval:  0.8806
# epoch time: 5365.261 ms, per step time: 5.365 ms

# %% [markdown]
# 观察新模型loss的变化

# %%
plot_loss(hist)

# %% [markdown]
# 观察新模型accuracy变化

# %%
plot_accuracy(hist)

# %% [markdown]
# 载入最佳网络参数，并测试其accuracy与loss

# %%
# 使用准确率最高的参数组合建立模型，并测试其在验证集上的效果
best_param = mindspore.load_checkpoint(os.path.join(ckpt_path, 'best_param.ckpt'), net=network2)
res = model.eval(test_data, dataset_sink_mode=dataset_sink_mode)
print(res)
# Out:
# {'accuracy': 0.8844, 'loss': 0.44788292920589445}

# %% [markdown]
# ## 效果展示

# %%
#创建图像标签列表
category_dict = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',
                 6:'frog',7:'horse',8:'ship',9:'truck'}

data_path=os.path.join('data', '10-verify-bin')

demo_data = create_dataset(test_path, batch_size=1, usage='test')

# 将数据标准化至0~1区间
def normalize(data):
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# 设置图像大小
plt.figure(figsize=(10,10))
i = 1
# 打印9张子图
for dic in demo_data.create_dict_iterator():
    # 预测单张图片
    input_img = dic['image']
    output = model.predict(input_img)
    predict = np.argmax(output.asnumpy(),axis=1)[0] # 反馈可能性最大的类别
    
    # 可视化
    plt.subplot(3,3,i)
    input_image = np.squeeze(input_img.asnumpy(),axis=0) # 删除batch维度，方便可视化
    input_image = input_image.transpose(1,2,0) # CHW转HWC，方便可视化
    input_image = normalize(input_image) # 重新标准化，方便可视化
    plt.imshow(input_image)
    plt.axis('off')
    plt.title('True: %s\n Predict: %s'%(category_dict[dic['label'].asnumpy().item()],category_dict[predict]))
    i +=1
    if i > 9 :
        break

plt.show()

# %% [markdown]
# ## 思考
# 1. 为何在数据增强前要加入 if usage == 'train' 的判断式？
#     * 答：数据增强的目的是提供模型更多不同的训练数据，评估是不需要做数据增强。
# 2. 有哪些数据增强的方法（举例）？
#     * 答：随机剪裁、随机翻转、随机旋转等
# 1. 什么是一个step？
#     * 答：一个step指一个batch送入网络中完成一次前向计算及反向传播的过程。
# 2. 编写自定义回调函数需继承什么基类？
#     * 答：Callback基类
# 3. 如何在自定义回调函数中获取训练过程中的重要信息（损失函数、优化器、当前的epoch数等）？
#     * 答：通过run_context.original_args()方法可以获取到cb_params字典，字典里会包含训练过程中的重要信息。
# 1. 本实验的模型欠拟合，可通过增加网络复杂度优化模型。如果模型过拟合，常见的处理方法有哪些？
#     * 答：L1，L2正则化，Early stopping，增加数据集，增加噪声，添加dropout层等。
# 6. 如何理解dataset sink mode？
#     * dataset_sink_mode=True时，可以这样简单的理解：Model中仅建立数据通道与执行网络之间的连接关系，不会直接将数据喂给网络。数据会通过数据通道(pipeline)下发到卡上，网络在卡上执行时会直接从对应的数据通道中获取数据。在这种模式下，数据下发与网络执行可以并行，单个epoch的训练过程中host与device之间不会交互，因此能提升性能，也因此打屏以epoch递增。
#     * dataset_sink_mode=False，没有使用数据下沉模式。这时候数据不会通过通道直接向Device下发，Model会将数据一个batch一个batch得取出，喂给网络。在这种模式下，每个step结束，host都可以获取device上网络的执行结果，因此打屏以step递增。
# 7. 为什么本实验的模型在训练集的loss波动较大，且比在测试集高？
#     * 答：因为训练集做了数据增强，有些经过剪裁或翻转的图片较难辨认。

# %% [markdown]
# ## 实验总结
# 本章提供了一个基于开源框架MindSpore的图像识别实验。该实验演示了如何利用开源框架MindSpore完成CIFAR-10图像识别任务。本章对实验做了详尽的剖析，阐明了整个实验功能、结构与流程，详细解释了如何解析数据、如何构建深度学习模型、如何自定义回调函数以及保存等内容，并且展示了模型的优化与调参。学员可以在该实验的基础上开发更有针对性的应用实验。

# %% [markdown]
# ## 挑战
# 本实验的最终模型准确率仍然不高，尝试将模型准确率提升到90%以上
